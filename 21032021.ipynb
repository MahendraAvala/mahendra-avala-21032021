# %% [markdown]
# **Name: Mahendra**

# %%
#Importing the required libraries
import pandas as pd
import numpy as np
from plotnine import aes, geom_line, geom_point, ggplot,labs, geom_boxplot

# %%
#Dataset assignment to a variable
text=pd.read_csv(r"C:\\Mahendra\ADS1\Nairn Weather Data.csv", low_memory=False)

# %%
#Boxplot analysis- Highest Temperature for different months in Nairn
ggplot(text) + aes(x="MON", y="HIGHEST_TEMP") + geom_boxplot()
# Out:
# <ggplot: (143629901135)>

# %%
#Boxplot analysis - Air frost days for different months in Nairn
ggplot(text) + aes(x="MON", y="AIR_FROST_DAYS") + geom_boxplot()
# Out:
# <ggplot: (143635654732)>

# %%
#Lineplot analysis- Sun duration for different months in Nairn
ggplot(text) + aes(x="MON", y="SUN_DURATION_HRS") + geom_line()
# Out:
# <ggplot: (143635258986)>
